# %%
a = 123
print(a)
# Out:
# 123

# %%
a = 'hello'
print(a)
# Out:
# hello

# %%
a,b = 10, 4
print(a+b)
print(a-b)
print(a/b)
print(a//b)
print(a^b)
# Out:
# 14
# 6
# 2.5
# 2
# 14

# %% [markdown]
# head = "python"
# tail = " is fan "
#
# head + tail

# %% [markdown]
# head * 2

# %%
head = "python"
tail = " is fan "

head + tail
# Out:
# 'python is fan '

# %%
head * 2
# Out:
# 'pythonpython'

# %%
len(head)
# Out:
# 6

# %%
a = "life is too short, you need python"
a[4]
# Out:
# ' '

# %%
#슬라이싱
print(a[0:-7])
# Out:
# life is too short, you need

# %%
print(a[0:11],a[18:])
# Out:
# life is too  you need python

# %%
a = "20260512Rainy"

print(a[:8])

print(a[8:])
# Out:
# 20260512
# Rainy

# %%
a = 20
print("현재 온도는",a,"입니다")

print("현재 온도는 %d 입니다" % a)

print("현재 온도는 {} 입니다".format(a))

print(f"현재 온도는 {a} 입니다")
# Out:
# 현재 온도는 20 입니다
# 현재 온도는 20 입니다
# 현재 온도는 20 입니다
# 현재 온도는 20 입니다

# %%
b = "hobby"

b.count('c')
# Out:
# 0

# %%
a = []
b = [1,3,5,7,9]
c = list()
d = ['life', 'is', 'too', 'short']
f = [1,2, 'life', 'is']
g = [1,2, 'too', 'short']

# %%
print(b[:2])
# Out:
# [1, 3]

# %%
a + b
# Out:
# [1, 3, 5, 7, 9]

# %%
b + d
b * 2
# Out:
# [1, 3, 5, 7, 9, 1, 3, 5, 7, 9]

# %%
print(a)
print(c)
# Out:
# []
# []

# %%
a.append('Hello')
print(a)
# Out:
# ['Hello', 'Hello', 'Hello']

# %%
c.append(['Hello', 'bye'])

# %%
c
# Out:
# [['Hello', 'bye'], ['Hello', 'bye']]

# %%
#리스트 정렬

a = [1,4,2,3]

a.sort()

a
# Out:
# [1, 2, 3, 4]

# %%
a.sort(reverse=True)
a
# Out:
# [4, 3, 2, 1]

# %%
a.index(2)
# Out:
# 2

# %%
# append() = 뒤에 삽입
# insert() = 특정 위치에 삽입

b.insert(3, 88)
b
# Out:
# [1, 3, 5, 88, 88, 7, 9]

# %%
# remove = 제거
b.remove(1)
b
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[96], line 2
#       1 # remove = 제거
# ----> 2 b.remove(1)
#       3 b
#
# ValueError: list.remove(x): x not in list

# %%
b.pop()
b
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[102], line 1
# ----> 1 b.pop()
#       2 b
#
# IndexError: pop from empty list

# %%
b.count(1)
b
# Out:
# []

# %%
## 튜플
#튜플은 리스트와유사하나, 요솟값을 변경할 수 없다.
#
# Out:
#   Cell In[105], line 2
#     - 튜플은 리스트와유사하나, 요솟값을 변경할 수 없다.
#     ^
# IndentationError: unexpected indent

# %%
t1 = ()
t2 = (1,)
t3 = 1,2,3
t4 = (1,2,3)
t5 = ('a', 'b', ('ab', 'cd'))
